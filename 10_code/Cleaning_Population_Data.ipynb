# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_rows",200, "display.max_columns",200)

# %% [markdown]
# Reading in the population files - (i) 2000 - 2009 (ii) 2010 - 2020

# %%
raw_pre_2010 = pd.read_csv("C:\\Users\\deeks\\Documents\\MIDS\\IDS 720_Practising Data Science\\Mid-Sem project\\Gitdata\\pds2021-opioids-team-2-ids720\\00_source_data\\population_data\\2000 - 2010.csv", encoding = "ISO8859-1")
raw_post_2010 = pd.read_csv("C:\\Users\\deeks\\Documents\\MIDS\\IDS 720_Practising Data Science\\Mid-Sem project\\Gitdata\\pds2021-opioids-team-2-ids720\\00_source_data\\population_data\\2010 - 2020.csv", encoding = "ISO8859-1")

# %%
raw_pre_2010.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#   CENSUS2000POP  ESTIMATESBASE2000  POPESTIMATE2000  POPESTIMATE2001  \
# 0       4447100            4447382          4451849          4464034
# 1         43671              43671            43872            44434
# 2        140415             140415           141358           144988
# 3         29038              29038            29035            29223
# 4         20826              19889            19936            20942
#
#    POPESTIMATE2002  POPESTIMATE2003  POPESTIMATE2004  POPESTIMATE2005  \
# ...

# %%
raw_post_2010.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#   CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# 0       4779736            4780118          4785514          4799642
# 1         54571              54582            54761            55229
# 2        182265             182263           183121           186579
# 3         27457              27454            27325            27344
# 4         22915              22904            22858            22736
#
#    POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# ...

# %%
raw_post_2010.iloc[:,0:20].columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
#        'POPESTIMATE2014', 'POPESTIMATE2015', 'POPESTIMATE2016',
#        'POPESTIMATE2017', 'POPESTIMATE2018', 'POPESTIMATE2019',
#        'POPESTIMATE2020'],
#       dtype='object')

# %%
keepcols_pre = ['STATE', 'COUNTY', 'STNAME', 'CTYNAME',
       'CENSUS2000POP',
       'POPESTIMATE2001', 'POPESTIMATE2002', 'POPESTIMATE2003',
       'POPESTIMATE2004', 'POPESTIMATE2005', 'POPESTIMATE2006',
       'POPESTIMATE2007', 'POPESTIMATE2008', 'POPESTIMATE2009']

keepcols_post = ['STATE', 'COUNTY', 'STNAME', 'CTYNAME',
       'CENSUS2010POP',
       'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
       'POPESTIMATE2014', 'POPESTIMATE2015', 'POPESTIMATE2016',
       'POPESTIMATE2017', 'POPESTIMATE2018', 'POPESTIMATE2019','POPESTIMATE2020']

raw_pre_2010 = raw_pre_2010.loc[:,raw_pre_2010.columns.isin(keepcols_pre)]
raw_post_2010 = raw_post_2010.loc[:,raw_post_2010.columns.isin(keepcols_post)]

# %%
raw_pre_2010.shape
raw_post_2010.shape
# Out:
# (3194, 14)
# (3194, 15)

# %%
raw_popn_merged = raw_pre_2010.merge(raw_post_2010, on=["STATE","COUNTY","STNAME","CTYNAME"], how="left", validate="1:1")
raw_popn_merged.head()
# Out:
#    STATE  COUNTY   STNAME         CTYNAME CENSUS2000POP  POPESTIMATE2001  \
# 0      1       0  Alabama         Alabama       4447100          4464034
# 1      1       1  Alabama  Autauga County         43671            44434
# 2      1       3  Alabama  Baldwin County        140415           144988
# 3      1       5  Alabama  Barbour County         29038            29223
# 4      1       7  Alabama     Bibb County         20826            20942
#
#    POPESTIMATE2002  POPESTIMATE2003  POPESTIMATE2004  POPESTIMATE2005  \
# 0          4472420          4490591          4512190          4545049
# 1            45157            45762            46933            47870
# 2           148141           151707           156573           162564
# 3            29289            29480            29458            29452
# 4            20983            21037            21208            21375
#
#    POPESTIMATE2006  POPESTIMATE2007  POPESTIMATE2008  POPESTIMATE2009  \
# ...

# %%
raw_popn_merged = raw_popn_merged.loc[raw_popn_merged["STNAME"] != raw_popn_merged["CTYNAME"]]
raw_popn_merged.shape
# Out:
# (3142, 25)

# %%
raw_popn_merged = raw_popn_merged.loc[raw_popn_merged["STNAME"]!="Alaska"]
raw_popn_merged.shape
# Out:
# (3113, 25)

# %%
# keep_states = ["Florida","Texas","Washington","Maryland","Delaware","New York"]

# %%
raw_popn_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3113 entries, 1 to 3193
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STATE            3113 non-null   int64
#  1   COUNTY           3113 non-null   int64
#  2   STNAME           3113 non-null   object
#  3   CTYNAME          3113 non-null   object
#  4   CENSUS2000POP    3113 non-null   object
#  5   POPESTIMATE2001  3113 non-null   int64
#  6   POPESTIMATE2002  3113 non-null   int64
#  7   POPESTIMATE2003  3113 non-null   int64
#  8   POPESTIMATE2004  3113 non-null   int64
#  9   POPESTIMATE2005  3113 non-null   int64
#  10  POPESTIMATE2006  3113 non-null   int64
#  11  POPESTIMATE2007  3113 non-null   int64
#  12  POPESTIMATE2008  3113 non-null   int64
#  13  POPESTIMATE2009  3113 non-null   int64
#  14  CENSUS2010POP    3110 non-null   object
#  15  POPESTIMATE2011  3110 non-null   float64
#  16  POPESTIMATE2012  3110 non-null   float64
# ...

# %%
(raw_popn_merged.isna().sum()/len(raw_popn_merged)).apply(lambda x:"{:.2%}".format(x))
# Out:
# STATE              0.00%
# COUNTY             0.00%
# STNAME             0.00%
# CTYNAME            0.00%
# CENSUS2000POP      0.00%
# POPESTIMATE2001    0.00%
# POPESTIMATE2002    0.00%
# POPESTIMATE2003    0.00%
# POPESTIMATE2004    0.00%
# POPESTIMATE2005    0.00%
# POPESTIMATE2006    0.00%
# POPESTIMATE2007    0.00%
# POPESTIMATE2008    0.00%
# POPESTIMATE2009    0.00%
# CENSUS2010POP      0.10%
# POPESTIMATE2011    0.10%
# POPESTIMATE2012    0.10%
# POPESTIMATE2013    0.10%
# POPESTIMATE2014    0.10%
# POPESTIMATE2015    0.10%
# POPESTIMATE2016    0.10%
# POPESTIMATE2017    0.10%
# POPESTIMATE2018    0.10%
# POPESTIMATE2019    0.10%
# POPESTIMATE2020    0.10%
# dtype: object

# %%
raw_popn_merged.loc[raw_popn_merged["CENSUS2010POP"].isnull()]
# Out:
#       STATE  COUNTY        STNAME          CTYNAME CENSUS2000POP  \
# 1161     22      59     Louisiana  La Salle Parish         14282
# 2459     46     113  South Dakota   Shannon County         12466
# 2963     51     515      Virginia     Bedford city          6299
#
#       POPESTIMATE2001  POPESTIMATE2002  POPESTIMATE2003  POPESTIMATE2004  \
# 1161            14119            14187            14094            14023
# 2459            12668            12982            13132            13157
# 2963             6333             6290             6246             6239
#
#       POPESTIMATE2005  POPESTIMATE2006  POPESTIMATE2007  POPESTIMATE2008  \
# 1161            13887            14008            13993            14012
# 2459            13352            13637            13606            13641
# 2963             6254             6243             6292             6315
#
#       POPESTIMATE2009 CENSUS2010POP  POPESTIMATE2011  POPESTIMATE2012  \
# ...

# %%
raw_popn_merged.rename({'CENSUS2000POP':'2000',
       'POPESTIMATE2001':'2001', 
       'POPESTIMATE2002':'2002',
       'POPESTIMATE2003':'2003',
       'POPESTIMATE2004':'2004',
       'POPESTIMATE2005':'2005',
       'POPESTIMATE2006':'2006',
       'POPESTIMATE2007':'2007',
       'POPESTIMATE2008':'2008',
       'POPESTIMATE2009':'2009',
       'CENSUS2010POP':'2010',
       'POPESTIMATE2011':'2011', 
       'POPESTIMATE2012':'2012',
       'POPESTIMATE2013':'2013',
       'POPESTIMATE2014':'2014',
       'POPESTIMATE2015':'2015',
       'POPESTIMATE2016':'2016',
       'POPESTIMATE2017':'2017',
       'POPESTIMATE2018':'2018',
       'POPESTIMATE2019':'2019',
       'POPESTIMATE2020':'2020'
       }, axis=1, inplace=True)

# %%
raw_popn_merged.head()
# Out:
#    STATE  COUNTY   STNAME         CTYNAME    2000    2001    2002    2003  \
# 1      1       1  Alabama  Autauga County   43671   44434   45157   45762
# 2      1       3  Alabama  Baldwin County  140415  144988  148141  151707
# 3      1       5  Alabama  Barbour County   29038   29223   29289   29480
# 4      1       7  Alabama     Bibb County   20826   20942   20983   21037
# 5      1       9  Alabama   Blount County   51024   51999   52775   53726
#
#      2004    2005    2006    2007    2008    2009    2010      2011      2012  \
# 1   46933   47870   49105   49834   50354   50756   54571   55229.0   54970.0
# 2  156573  162564  168516  172815  176212  179878  182265  186579.0  190203.0
# 3   29458   29452   29556   29736   29836   29737   27457   27344.0   27172.0
# 4   21208   21375   21285   21485   21589   21587   22915   22736.0   22657.0
# 5   54469   55035   55978   56866   57794   58345   57322   57561.0   57585.0
#
# ...

# %%
raw_popn_merged_melted = pd.melt(raw_popn_merged, id_vars=["STATE","COUNTY","STNAME","CTYNAME"], value_vars=['2000',
       '2001', '2002', '2003',
       '2004', '2005', '2006',
       '2007', '2008', '2009',
       '2010', '2011', '2012',
       '2013', '2014', '2015',
       '2016', '2017', '2018',
       '2019', '2020'       
       ], var_name="Year", value_name="Population")
raw_popn_merged_melted.head()
# Out:
#    STATE  COUNTY   STNAME         CTYNAME  Year Population
# 0      1       1  Alabama  Autauga County  2000      43671
# 1      1       3  Alabama  Baldwin County  2000     140415
# 2      1       5  Alabama  Barbour County  2000      29038
# 3      1       7  Alabama     Bibb County  2000      20826
# 4      1       9  Alabama   Blount County  2000      51024

# %%
raw_popn_merged_melted.isna().sum()
# Out:
# STATE          0
# COUNTY         0
# STNAME         0
# CTYNAME        0
# Year           0
# Population    33
# dtype: int64

# %%
raw_popn_merged_melted["Population"] = np.where(raw_popn_merged_melted["Population"]=="X",np.nan, raw_popn_merged_melted["Population"])

# %%
raw_popn_merged_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65373 entries, 0 to 65372
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STATE       65373 non-null  int64
#  1   COUNTY      65373 non-null  int64
#  2   STNAME      65373 non-null  object
#  3   CTYNAME     65373 non-null  object
#  4   Year        65373 non-null  object
#  5   Population  65339 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 3.0+ MB

# %%
raw_popn_merged_melted["Population"] = pd.to_numeric(raw_popn_merged_melted["Population"], errors='coerce')
raw_popn_merged_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65373 entries, 0 to 65372
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STATE       65373 non-null  int64
#  1   COUNTY      65373 non-null  int64
#  2   STNAME      65373 non-null  object
#  3   CTYNAME     65373 non-null  object
#  4   Year        65373 non-null  object
#  5   Population  65339 non-null  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 3.0+ MB

# %%
raw_popn_merged_melted.groupby(["STNAME"]).mean("Population").sort_values(by = "Population",ascending=False)
# Out:
#                 STATE      COUNTY     Population
# STNAME
# California        6.0   58.000000  641129.163383
# Massachusetts    25.0   14.000000  473228.731293
# Connecticut       9.0    8.000000  440998.970238
# Arizona           4.0   13.866667  426522.523810
# New Jersey       34.0   21.000000  415837.414966
# New York         36.0   62.000000  313240.926267
# Delaware         10.0    3.000000  296853.095238
# Florida          12.0   67.910448  282411.746979
# Hawaii           15.0    5.000000  266988.447619
# Maryland         24.0   44.958333  239884.833333
# Rhode Island     44.0    5.000000  211632.990476
# Pennsylvania     42.0   67.000000  188195.069652
# Washington       53.0   39.000000  173099.444444
# Nevada           32.0   45.529412  154979.310924
# New Hampshire    33.0   10.000000  131677.976190
# Ohio             39.0   88.000000  131200.340368
# Illinois         17.0  102.000000  124863.028478
# Michigan         26.0   83.000000  120281.593230
# ...

# %%
raw_popn_merged_melted.head()
# Out:
#    STATE  COUNTY   STNAME         CTYNAME  Year  Population
# 0      1       1  Alabama  Autauga County  2000     43671.0
# 1      1       3  Alabama  Baldwin County  2000    140415.0
# 2      1       5  Alabama  Barbour County  2000     29038.0
# 3      1       7  Alabama     Bibb County  2000     20826.0
# 4      1       9  Alabama   Blount County  2000     51024.0
