# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_rows",200, "display.max_columns",200)

# %% [markdown]
# Reading in the population files - (i) 2000 - 2009 (ii) 2010 - 2020

# %%
raw_pre_2010 = pd.read_csv("C:\\Users\\deeks\\Documents\\MIDS\\IDS 720_Practising Data Science\\Mid-Sem project\\Gitdata\\pds2021-opioids-team-2-ids720\\00_source_data\\population_data\\2000 - 2010.csv", encoding = "ISO8859-1")
raw_post_2010 = pd.read_csv("C:\\Users\\deeks\\Documents\\MIDS\\IDS 720_Practising Data Science\\Mid-Sem project\\Gitdata\\pds2021-opioids-team-2-ids720\\00_source_data\\population_data\\2010 - 2020.csv", encoding = "ISO8859-1")

# %%
raw_pre_2010.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#   CENSUS2000POP  ESTIMATESBASE2000  POPESTIMATE2000  POPESTIMATE2001  \
# 0       4447100            4447382          4451849          4464034
# 1         43671              43671            43872            44434
# 2        140415             140415           141358           144988
# 3         29038              29038            29035            29223
# 4         20826              19889            19936            20942
#
#    POPESTIMATE2002  POPESTIMATE2003  POPESTIMATE2004  POPESTIMATE2005  \
# ...

# %%
raw_post_2010.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#   CENSUS2000POP  ESTIMATESBASE2000  POPESTIMATE2000  POPESTIMATE2001  \
# 0       4447100            4447382          4451849          4464034
# 1         43671              43671            43872            44434
# 2        140415             140415           141358           144988
# 3         29038              29038            29035            29223
# 4         20826              19889            19936            20942
#
#    POPESTIMATE2002  POPESTIMATE2003  POPESTIMATE2004  POPESTIMATE2005  \
# ...

# %%
raw_pre_2010.iloc[:,0:19].columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2000POP', 'ESTIMATESBASE2000', 'POPESTIMATE2000',
#        'POPESTIMATE2001', 'POPESTIMATE2002', 'POPESTIMATE2003',
#        'POPESTIMATE2004', 'POPESTIMATE2005', 'POPESTIMATE2006',
#        'POPESTIMATE2007', 'POPESTIMATE2008', 'POPESTIMATE2009'],
#       dtype='object')

# %%
raw_post_2010.iloc[:,0:19].columns
# Out:
# Index(['STATE', 'COUNTY', 'STNAME', 'CTYNAME', 'CENSUS2000POP',
#        'POPESTIMATE2001', 'POPESTIMATE2002', 'POPESTIMATE2003',
#        'POPESTIMATE2004', 'POPESTIMATE2005', 'POPESTIMATE2006',
#        'POPESTIMATE2007', 'POPESTIMATE2008', 'POPESTIMATE2009'],
#       dtype='object')

# %%
keepcols = ['STATE', 'COUNTY', 'STNAME', 'CTYNAME',
       'CENSUS2000POP',
       'POPESTIMATE2001', 'POPESTIMATE2002', 'POPESTIMATE2003',
       'POPESTIMATE2004', 'POPESTIMATE2005', 'POPESTIMATE2006',
       'POPESTIMATE2007', 'POPESTIMATE2008', 'POPESTIMATE2009']

raw_pre_2010 = raw_pre_2010.loc[:,raw_pre_2010.columns.isin(keepcols)]
raw_post_2010 = raw_post_2010.loc[:,raw_post_2010.columns.isin(keepcols)]

# %%
raw_post_2010.head()
# Out:
#    STATE  COUNTY   STNAME         CTYNAME CENSUS2000POP  POPESTIMATE2001  \
# 0      1       0  Alabama         Alabama       4447100          4464034
# 1      1       1  Alabama  Autauga County         43671            44434
# 2      1       3  Alabama  Baldwin County        140415           144988
# 3      1       5  Alabama  Barbour County         29038            29223
# 4      1       7  Alabama     Bibb County         20826            20942
#
#    POPESTIMATE2002  POPESTIMATE2003  POPESTIMATE2004  POPESTIMATE2005  \
# 0          4472420          4490591          4512190          4545049
# 1            45157            45762            46933            47870
# 2           148141           151707           156573           162564
# 3            29289            29480            29458            29452
# 4            20983            21037            21208            21375
#
#    POPESTIMATE2006  POPESTIMATE2007  POPESTIMATE2008  POPESTIMATE2009
# ...

# %%
raw_pre_2010.shape
raw_post_2010.shape
# Out:
# (3194, 14)
# (3194, 14)

# %%
raw_popn_merged = pd.concat([raw_pre_2010,raw_post_2010], ignore_index=True)
raw_popn_merged.shape
# Out:
# (6388, 14)

# %%
raw_popn_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6388 entries, 0 to 6387
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STATE            6388 non-null   int64
#  1   COUNTY           6388 non-null   int64
#  2   STNAME           6388 non-null   object
#  3   CTYNAME          6388 non-null   object
#  4   CENSUS2000POP    6388 non-null   object
#  5   POPESTIMATE2001  6388 non-null   int64
#  6   POPESTIMATE2002  6388 non-null   int64
#  7   POPESTIMATE2003  6388 non-null   int64
#  8   POPESTIMATE2004  6388 non-null   int64
#  9   POPESTIMATE2005  6388 non-null   int64
#  10  POPESTIMATE2006  6388 non-null   int64
#  11  POPESTIMATE2007  6388 non-null   int64
#  12  POPESTIMATE2008  6388 non-null   int64
#  13  POPESTIMATE2009  6388 non-null   int64
# dtypes: int64(11), object(3)
# memory usage: 698.8+ KB

# %%
raw_popn_merged = raw_popn_merged.loc[raw_popn_merged["STNAME"] != raw_popn_merged["CTYNAME"]]
raw_popn_merged.head()
# Out:
#    STATE  COUNTY   STNAME         CTYNAME CENSUS2000POP  POPESTIMATE2001  \
# 1      1       1  Alabama  Autauga County         43671            44434
# 2      1       3  Alabama  Baldwin County        140415           144988
# 3      1       5  Alabama  Barbour County         29038            29223
# 4      1       7  Alabama     Bibb County         20826            20942
# 5      1       9  Alabama   Blount County         51024            51999
#
#    POPESTIMATE2002  POPESTIMATE2003  POPESTIMATE2004  POPESTIMATE2005  \
# 1            45157            45762            46933            47870
# 2           148141           151707           156573           162564
# 3            29289            29480            29458            29452
# 4            20983            21037            21208            21375
# 5            52775            53726            54469            55035
#
#    POPESTIMATE2006  POPESTIMATE2007  POPESTIMATE2008  POPESTIMATE2009
# ...

# %%
raw_popn_merged.rename({'CENSUS2000POP':'2000',
       'POPESTIMATE2001':'2001', 
       'POPESTIMATE2002':'2002',
       'POPESTIMATE2003':'2003',
       'POPESTIMATE2004':'2004',
       'POPESTIMATE2005':'2005',
       'POPESTIMATE2006':'2006',
       'POPESTIMATE2007':'2007',
       'POPESTIMATE2008':'2008',
       'POPESTIMATE2009':'2009'
       }, axis=1, inplace=True)

# %%
raw_popn_merged.head()
# Out:
#    STATE  COUNTY   STNAME         CTYNAME    2000    2001    2002    2003  \
# 1      1       1  Alabama  Autauga County   43671   44434   45157   45762
# 2      1       3  Alabama  Baldwin County  140415  144988  148141  151707
# 3      1       5  Alabama  Barbour County   29038   29223   29289   29480
# 4      1       7  Alabama     Bibb County   20826   20942   20983   21037
# 5      1       9  Alabama   Blount County   51024   51999   52775   53726
#
#      2004    2005    2006    2007    2008    2009
# 1   46933   47870   49105   49834   50354   50756
# 2  156573  162564  168516  172815  176212  179878
# 3   29458   29452   29556   29736   29836   29737
# 4   21208   21375   21285   21485   21589   21587
# 5   54469   55035   55978   56866   57794   58345

# %%
raw_popn_merged_melted = pd.melt(raw_popn_merged, id_vars=["STATE","COUNTY","STNAME","CTYNAME"], value_vars=['2000',
       '2001', '2002', '2003',
       '2004', '2005', '2006',
       '2007', '2008', '2009'], var_name="Year", value_name="Population")
raw_popn_merged_melted.head()
# Out:
#    STATE  COUNTY   STNAME         CTYNAME  Year Population
# 0      1       1  Alabama  Autauga County  2000      43671
# 1      1       3  Alabama  Baldwin County  2000     140415
# 2      1       5  Alabama  Barbour County  2000      29038
# 3      1       7  Alabama     Bibb County  2000      20826
# 4      1       9  Alabama   Blount County  2000      51024

# %%
raw_popn_merged_melted["Year"].value_counts()
# Out:
# 2000    6284
# 2001    6284
# 2002    6284
# 2003    6284
# 2004    6284
# 2005    6284
# 2006    6284
# 2007    6284
# 2008    6284
# 2009    6284
# Name: Year, dtype: int64
